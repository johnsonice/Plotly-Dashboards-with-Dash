# %%
from gensim import corpora
from gensim.models import LdaModel
import numpy as np
import sys
import os
import gensim
import pickle
import pandas as pd
import datetime
import time

# %%
## load text data 
def load_data(data_processed_folder,processed_file_name):
    file_path = os.path.join(data_processed_folder,processed_file_name)
    with open(file_path,'rb') as f:
        dataset = pickle.load(f)
        for r in dataset:
            r[4] = [w for sentance in r[4] for w in sentance]
            r.append(vocab_dict.doc2bow(r[4]))
   
    ## transformed to dataframe
    dataset = pd.DataFrame(dataset,columns=['id','country','year','title','tokens','text','bow'])
    dataset['length'] = dataset.tokens.apply(len)

    return dataset

def get_topics(model,bow):
    return model[bow]

def get_topics_list(model,bows):
    
    res = [*map(lambda x: model.get_document_topics(x), bows)]

    return res 


def merge_transform_topic_df(topic_model_res, dataset,
                             keep_columns= ['id','country','year','title','text','length']):
    
    doc_topic_df = pd.DataFrame(topic_model_res)
    doc_topic_df['paragraph_id'] = doc_topic_df.index.to_list()
    
    #reshape from wide to long
    doc_topic_df  = doc_topic_df.melt(id_vars='paragraph_id')
    doc_topic_df = doc_topic_df[doc_topic_df['value'].notnull()]
    doc_topic_df['gensim_topic'] = doc_topic_df['value'].apply(lambda x: x[0])
    doc_topic_df['probability'] = doc_topic_df['value'].apply(lambda x: x[1])
    doc_topic_df  = doc_topic_df[['paragraph_id','gensim_topic', 'probability']]
    
    ## merge database
    doc_topic_full_df = pd.merge(dataset[keep_columns],doc_topic_df,left_index=True,right_on=['paragraph_id'])
     
    return doc_topic_full_df

def get_topic_words_df(model, top_n=30):
    
    topics_words_matrix = np.array([[w for w,p in model.show_topic(topicid=i,topn=top_n)] 
                         for i in range(n_topics)])
    columns_n = ['word{}'.format(str(i)) for i in range(top_n)]
    topic_words_df = pd.DataFrame(topics_words_matrix,columns=columns_n)
    
    return topic_words_df

# %%
data_folder = '../../data/'
model_folder = '../../model/'
model_path = os.path.join('../../model/mallet_as_gensim_weights_50_2019_02_12')
data_processed_folder = os.path.join(data_folder,'processed')
processed_file_name = 'lemma_corpus_with_n_with_meta.p'
results_folder = os.path.join(data_folder,'results','temp_results')

## gensim dictionrary file 
dictionary_path = os.path.join(data_processed_folder,'dictionary.dict')

## load model 
lda_gensim = LdaModel.load(model_path)
vocab_dict = corpora.Dictionary.load(dictionary_path)
print('Topic Model loaded successfully...')


## set up paramaters
n_topics = lda_gensim.num_topics
n_words = 30

## test flag
test = False

## load data 
dataset = load_data(data_processed_folder,processed_file_name)

dataset
# Out:
# Topic Model loaded successfully...
#            id             country  year  \
# 0         102  Russian Federation  2017
# 1         102  Russian Federation  2017
# 2         102  Russian Federation  2017
# 3         102  Russian Federation  2017
# 4         102  Russian Federation  2017
# 5         102  Russian Federation  2017
# 6         102  Russian Federation  2017
# 7         102  Russian Federation  2017
# 8         102  Russian Federation  2017
# 9         102  Russian Federation  2017
# 10        102  Russian Federation  2017
# 19      [authority, commit, fiscal, consolidation, ame...
# 20                  [evaluate, new, propose, fiscal_rule]
# 21      [evaluate, authority, propose, new, fiscal_rul...
# 22      [fiscal, federalism, regional, economic, perfo...
# 23      [analyze, economic, performance, region, relat...
# 24      [nonetheless, federal, transfer, less, effecti...
# 25      [regional, dependence, transfer, likely, conti...
# 26      [fiscal_policy, federal, level, support, devel...
# 27      [monetary_policy, easing, resume, stay, hold, ...
# 28      [recommend, monetary, easing, continue, gradua...
# 29      [recommend, shift, communication, strategy, ho...
# ...                                                   ...
# 149749  [njrs, acknowledge, urgent, need, reform, judi...
# 149750  [increase, cooperation, context, accession, pr...
# 149751  [progress, make, address, soes, former, privat...
# 149752  [support, authority, focus, improve, business,...
# 149753  [authority, agree, support, formal, private_se...
# 149754  [persistent, unemployment, low, labor_force_pa...
# 149755  [urge, authority, press, ahead, resolution, re...
# 149756  [elektroprivreda, srbije, eps, problem, electr...
# 149757  [srbijagas, company, financial, position, impr...
# 149758  [railway, implementation, systemization, plan,...
# 149759  [rtb, bor, recover, international, copper, pri...
# 149760  [petrohemija, msk, azotara, date, company, ser...
# 149761  [resavica, comprehensive, restructuring, plan,...
# 149762  [galenika, privatization, tender, early, fail,...
# 149763  [proposes, update, program, conditionality, me...
# 149764  [prior, action, set, adoption, new, job, catal...
# 149765  [performance, criterion, general, government, ...
# 149766  [sb, propose, modify, reset, new, plan, admini...
# 149767  [new, sb, propose, support, structural_reform,...
# 149768  [capacity, meet, potential, repayment, obligat...
# 149769  [small, sovereign, arrears, outstanding, inten...
# 149770  [achieve, impressive, economic, improvement, l...
# 149771  [strengthened, commitment, need, ensure, full,...
# 149772  [need, build, strong, institution, consolidate...
# 149773  [contain, mandatory, current, spending, remain...
# 149774  [monetary_policy, succeed, keep, inflation, fi...
# 149775  [financial_sector, reform, successful, element...
# 149776  [business, environment, strengthen, significan...
# 149777  [reform, public_investment_management, need, i...
# 149778  [light, progress, far, authority, policy, comm...
#
#                                                      text  \
# 0       <Title> Context: Leveraging the Tailwinds of H...
# 1       1. The Russian economy proved to be more resil...
# 2       2. The recovery in oil prices is supporting th...
# 3       3. The need for a new growth model to accelera...
# 4       4. The economic recovery is gaining pace (Figu...
# 5       5. The current account surplus declined as the...
# 6       6. Higher oil prices, easier financial conditi...
# 7       7. However, medium-term prospects are subdued....
# 8       8. Short-term risks have declined. Risks to th...
# 9       9. The authorities agreed with staff that 2017...
# 10      <Title> Policy Discussions: Sowing the Seeds o...
# 11      The discussions focused on policies needed to ...
# 12      <Title> A. Fiscal Policy: Underpinning Consoli...
# 13      10. The authorities approved an ambitious medi...
# 14      11. The authorities amended the 2017 budget in...
# 15      12. A new mechanism to save oil revenues was a...
# 16      13. The authorities are designing a new fiscal...
# 17      14. Staff agreed with the pace of adjustment b...
# 18      15. Staff supported a reinstatement of a fisca...
# 19      16. The authorities are committed to fiscal co...
# 20      <Title> Evaluating Russia’s New Proposed Fisca...
# 21      We evaluate the authorities proposed new fisca...
# 22      <Title> Fiscal Federalism and Regional Economi...
# 23      Staff analyzed the economic performance of reg...
# 24      Nonetheless, federal transfers have been less ...
# 25      Regional dependence on transfers will likely c...
# 26      Fiscal policy at the federal level should supp...
# 27      17. Monetary policy easing has resumed (Figure...
# 28      18. Staff recommended that further monetary ea...
# 29      19. Staff recommended that the CBR shift its c...
# ...                                                   ...
# 149749  The 2013-18 NJRS acknowledges the urgent need ...
# 149750  Increased cooperation with the EU in the conte...
# 149751  35. Progress is being made in addressing the S...
# 149752  36. Staff supported the authorities’ focus on ...
# 149753  37. The authorities agreed that supporting the...
# 149754  38. Persistent unemployment and low labor forc...
# 149755  39. Staff urged the authorities to press ahead...
# 149756  Elektroprivreda Srbije (EPS). Problems with el...
# 149757  Srbijagas: The company’s financial position ha...
# 149758  Railways of Serbia. The implementation of the ...
# 149759  RTB Bor. Recovering international copper price...
# 149760  Petrohemija, MSK, and Azotara. To date all thr...
# 149761  Resavica. A comprehensive restructuring plan i...
# 149762  Galenika. A privatization tender in early 2017...
# 149763  40. Staff proposes updated program conditional...
# 149764  A prior action was set on the adoption of a ne...
# 149765  The performance criterion on the general gover...
# 149766  One SB is proposed to be modified and reset. T...
# 149767  New SBs are proposed with a view to support th...
# 149768  41. Serbia’s capacity to meet potential repaym...
# 149769  42. Serbia has small sovereign arrears outstan...
# 149770  43. Serbia has achieved an impressive economic...
# 149771  44. Strengthened commitment is needed to ensur...
# 149772  45. Serbia also needs to build stronger instit...
# 149773  46. Containing mandatory current spending rema...
# 149774  47. Monetary policy has succeeded in keeping i...
# 149775  48. Financial sector reforms have been one of ...
# 149776  49. The business environment has strengthened ...
# 149777  50. Reforms to public investment management al...
# 149778  51. In light of the progress so far and the au...
#
#                                                       bow  length
# 0        [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]       6
# 1       [(6, 1), (7, 1), (8, 1), (9, 1), (10, 1), (11,...      41
# 2       [(1, 1), (3, 2), (12, 2), (35, 1), (38, 1), (4...      64
# 3       [(3, 1), (8, 1), (12, 2), (18, 1), (22, 2), (4...      66
# 4       [(46, 1), (79, 2), (85, 1), (87, 2), (120, 1),...      41
# 5       [(3, 2), (12, 1), (15, 1), (30, 1), (55, 1), (...      70
# 6       [(0, 1), (1, 2), (3, 2), (12, 1), (17, 2), (33...      75
# 7       [(3, 1), (17, 1), (22, 1), (30, 1), (39, 1), (...      45
# 8       [(1, 1), (7, 1), (17, 2), (25, 2), (27, 1), (3...      82
# 9       [(3, 1), (6, 1), (9, 1), (12, 4), (15, 2), (16...      82
# 10      [(30, 1), (85, 1), (174, 1), (347, 1), (348, 1...       7
# 11      [(1, 1), (3, 2), (5, 1), (12, 2), (30, 1), (51...      62
# 12      [(254, 1), (334, 1), (353, 1), (380, 1), (381,...       5
# 13      [(1, 2), (3, 1), (6, 1), (50, 1), (65, 1), (13...      76
# 14      [(1, 2), (6, 2), (37, 1), (69, 1), (162, 2), (...      43
# 15      [(3, 2), (33, 1), (137, 1), (158, 1), (168, 1)...      70
# 16      [(3, 2), (6, 2), (13, 1), (80, 1), (188, 1), (...      47
# 17      [(3, 1), (6, 1), (7, 1), (20, 5), (26, 1), (27...     121
# 18      [(1, 1), (3, 4), (7, 1), (20, 3), (30, 1), (65...     129
# 19      [(1, 2), (3, 3), (6, 1), (12, 1), (20, 2), (51...     128
# 20               [(361, 1), (467, 1), (593, 1), (653, 1)]       4
# 21      [(1, 3), (3, 9), (6, 4), (12, 1), (20, 3), (25...     149
# 22      [(20, 1), (158, 1), (548, 1), (693, 1), (694, 1)]       5
# 23      [(1, 1), (13, 1), (20, 2), (22, 1), (25, 2), (...      63
# 24      [(1, 2), (8, 1), (13, 1), (20, 1), (25, 1), (3...      88
# 25      [(20, 1), (30, 1), (68, 1), (156, 1), (226, 1)...      40
# 26      [(3, 1), (16, 1), (22, 2), (25, 1), (51, 1), (...      66
# 27      [(0, 1), (6, 1), (16, 1), (19, 1), (50, 1), (6...      65
# 28      [(0, 1), (3, 1), (15, 1), (17, 1), (29, 1), (6...      88
# 29      [(29, 1), (119, 1), (127, 1), (166, 3), (180, ...      57
# ...                                                   ...     ...
# 149749  [(56, 1), (65, 1), (87, 1), (105, 1), (128, 2)...      59
# 149750  [(0, 1), (65, 1), (172, 1), (191, 1), (231, 1)...      29
# 149751  [(184, 3), (203, 1), (246, 2), (399, 1), (412,...      39
# 149752  [(6, 3), (30, 1), (45, 1), (65, 2), (87, 1), (...      65
# 149753  [(1, 1), (6, 5), (12, 2), (13, 1), (20, 1), (8...      82
# 149754  [(1, 1), (6, 1), (12, 1), (14, 1), (30, 2), (6...      68
# 149755  [(6, 2), (56, 1), (74, 1), (86, 1), (335, 1), ...      21
# 149756  [(6, 3), (47, 1), (65, 2), (87, 1), (116, 1), ...      81
# 149757  [(6, 1), (25, 1), (46, 1), (69, 1), (135, 1), ...      46
# 149758  [(184, 1), (277, 1), (355, 1), (399, 1), (431,...      28
# 149759  [(6, 1), (79, 1), (84, 1), (87, 1), (132, 1), ...      53
# 149760  [(6, 1), (59, 1), (163, 1), (168, 1), (173, 1)...      36
# 149761  [(6, 1), (15, 1), (56, 1), (146, 1), (177, 1),...      37
# 149762  [(6, 2), (190, 1), (201, 1), (321, 1), (467, 1...      30
# 149763  [(173, 1), (1602, 1), (2557, 1), (4125, 1), (5...       6
# 149764  [(45, 1), (87, 1), (94, 2), (247, 1), (341, 1)...      28
# 149765  [(163, 2), (188, 2), (247, 1), (355, 1), (386,...      24
# 149766  [(17, 1), (75, 1), (163, 1), (168, 1), (467, 1...      16
# 149767  [(87, 2), (163, 2), (269, 1), (287, 1), (320, ...      55
# 149768  [(1, 2), (17, 2), (47, 1), (124, 1), (132, 1),...      50
# 149769  [(6, 1), (163, 2), (199, 1), (233, 1), (248, 1...      27
# 149770  [(20, 1), (25, 1), (38, 1), (87, 1), (102, 1),...      53
# 149771  [(6, 1), (104, 1), (105, 1), (117, 1), (128, 1...      55
# 149772  [(1, 1), (20, 1), (87, 1), (117, 1), (122, 1),...      54
# 149773  [(1, 1), (20, 1), (33, 1), (68, 1), (74, 1), (...      46
# 149774  [(16, 2), (20, 1), (25, 1), (104, 1), (120, 1)...      69
# 149775  [(1, 1), (6, 1), (87, 1), (97, 1), (104, 1), (...      54
# 149776  [(32, 1), (38, 1), (105, 2), (117, 1), (120, 1...      50
# 149777  [(1, 2), (6, 1), (47, 1), (122, 1), (128, 1), ...      41
# 149778  [(6, 1), (30, 1), (87, 1), (102, 1), (538, 1),...      24
#
# [149779 rows x 8 columns]

# %%
if __name__ == '__main__':
    
    start_time = time.time()
    
    ## global folder path 
    data_folder = '../../data/'
    model_folder = '../../model/'
    model_path = os.path.join('../../model/mallet_as_gensim_weights_50_2019_02_12')
    data_processed_folder = os.path.join(data_folder,'processed')
    processed_file_name = 'lemma_corpus_with_n_with_meta.p'
    results_folder = os.path.join(data_folder,'results','temp_results')

    ## gensim dictionrary file 
    dictionary_path = os.path.join(data_processed_folder,'dictionary.dict')

    ## load model 
    lda_gensim = LdaModel.load(model_path)
    vocab_dict = corpora.Dictionary.load(dictionary_path)
    print('Topic Model loaded successfully...')
    
    
    ## set up paramaters
    n_topics = lda_gensim.num_topics
    n_words = 30

    ## test flag
    test = False

    ## load data 
    dataset = load_data(data_processed_folder,processed_file_name)
    if test:
        dataset = dataset.head(5)
        ## run one test
        try:
            x = get_topics(lda_gensim,dataset['bow'].head(1))
            print('Data Loaded, and topic model is valid.')
        except:
            raise Exception('your lda model weights are probably corrupted, please update weights.')

    ## generate results 
        ## get the results in sheet2
    topic_model_res = get_topics_list(lda_gensim,dataset['bow'])
    doc_topic_df = merge_transform_topic_df(topic_model_res,dataset)
    
    ##
    used_time = time.gmtime(time.time()-start_time)
    print('\nTime used to process topic probability: {}'.format(time.strftime("%H:%M:%S", used_time)))
    ## get results in sheet 1 
    topic_words_df= get_topic_words_df(lda_gensim, top_n=20)

    ## export to excel 
    now = datetime.datetime.now()
    now = now.strftime("%Y_%m_%d")
    writer = pd.ExcelWriter(path=os.path.join(results_folder,
                                              'Mallet_{}_topics_with_country_year_{}.xlsx'.format(n_topics, now)))
    #top_document_per_topic_df.to_excel(writer,'Topic and Top Document')
    topic_words_df.to_excel(writer, 'Toipc and Key Word')
    doc_topic_df.to_excel(writer, 'Document and Topic')
    writer.save()
    used_time = time.gmtime(time.time()-start_time)
    
    ## print out time used 
    print('Total time used for processing: {}'.format(time.strftime("%H:%M:%S", used_time)))
# Out:
# Topic Model loaded successfully...
#
# Time used to process topic probability: 00:02:13
# Total time used for processing: 00:04:38
